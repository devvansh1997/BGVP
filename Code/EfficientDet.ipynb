# %%
# !git clone https://github.com/bubbliiiing/efficientdet-pytorch.git
# Out:
# Cloning into 'efficientdet-pytorch'...
# remote: Enumerating objects: 455, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 455 (delta 11), reused 11 (delta 4), pack-reused 429
# Receiving objects: 100% (455/455), 5.52 MiB | 11.29 MiB/s, done.
# Resolving deltas: 100% (246/246), done.

# %%
# %cp -rv "/content/drive/MyDrive/VOCdevkit.zip" "/content/"
# Out:
# '/content/drive/MyDrive/VOCdevkit.zip' -> '/content/VOCdevkit.zip'

# %%
# !rm -rv /content/efficientdet-pytorch/VOCdevkit/VOC2007
# Out:
# removed '/content/efficientdet-pytorch/VOCdevkit/VOC2007/JPEGImages/README.md'
# removed directory '/content/efficientdet-pytorch/VOCdevkit/VOC2007/JPEGImages'
# removed '/content/efficientdet-pytorch/VOCdevkit/VOC2007/Annotations/README.md'
# removed directory '/content/efficientdet-pytorch/VOCdevkit/VOC2007/Annotations'
# removed '/content/efficientdet-pytorch/VOCdevkit/VOC2007/ImageSets/Main/README.md'
# removed directory '/content/efficientdet-pytorch/VOCdevkit/VOC2007/ImageSets/Main'
# removed directory '/content/efficientdet-pytorch/VOCdevkit/VOC2007/ImageSets'
# removed directory '/content/efficientdet-pytorch/VOCdevkit/VOC2007'

# %%
! unzip VOCdevkit.zip -d VOCdevkit
# Out:
# Archive:  VOCdevkit.zip
#    creating: VOCdevkit/VOCdevkit/VOC2007/
#    creating: VOCdevkit/VOCdevkit/VOC2007/.ipynb_checkpoints/
#   inflating: VOCdevkit/VOCdevkit/VOC2007/.ipynb_checkpoints/find_image_dimensions-checkpoint.ipynb
#    creating: VOCdevkit/VOCdevkit/VOC2007/Annotations/
#   inflating: VOCdevkit/VOCdevkit/VOC2007/Annotations/0_jpg.rf.b8137b948196edc006e9a63824b5b925.xml
#   inflating: VOCdevkit/VOCdevkit/VOC2007/Annotations/00001011_jpeg.rf.411bbbccf854d7cff79ae8848f90ba87.xml
#   inflating: VOCdevkit/VOCdevkit/VOC2007/Annotations/000022202200_jpeg.rf.76678baa6917165ddf383524d4b1652f.xml
#   inflating: VOCdevkit/VOCdevkit/VOC2007/Annotations/00003330033_jpeg.rf.bea4f3b44a44d4a4510e85c73aa8a635.xml
#   inflating: VOCdevkit/VOCdevkit/VOC2007/Annotations/003-Focusing-on-Those-Who-Need-Pedestrian-Ramps-the-Most_0_jpg.rf.45b8b7684f98da6764c10bf56b1bd10b.xml
# ...

# %%
# %cd /content/efficientdet-pytorch/
# !python voc_annotation.py
# Out:
# /content/efficientdet-pytorch
# Generate 2007_train.txt and 2007_val.txt for train.
# Generate 2007_train.txt and 2007_val.txt for train done.
# | children_wo_disability | 1511 |
# |  elderly_wo_disability |  731 |
# |         non_vulnerable | 2261 |
# |        with_disability |  840 |

# %%
# %cd /content/efficientdet-pytorch/
# !python train.py
# Out:
# /content/efficientdet-pytorch
# Load weights model_data/efficientdet-d0.pth.
#
# Successful Load Key: ['bifpn.0.p6_w1', 'bifpn.0.p5_w1', 'bifpn.0.p4_w1', 'bifpn.0.p3_w1', 'bifpn.0.p4_w2', 'bifpn.0.p5_w2', 'bifpn.0.p6_w2', 'bifpn.0.p7_w2', 'bifpn.0.conv6_up.depthwise_conv.conv.weight', 'bifpn.0.conv6_up.pointwise_conv.conv.weight', 'bifpn.0.conv6_up.pointwise_conv.conv.bias', 'bifpn.0.conv6_up.bn.weight', 'bifpn.0.conv6_up.bn.bias', 'bifpn.0.conv6_up.bn.running_mean', 'bifpn.0.conv6_up.bn.running_var', 'bifpn.0.conv6_up.bn.num_batches_tracked', 'bifpn.0.conv5_up.depthwise_conv.conv.weight', 'bifp ……
# Successful Load Key Num: 782
#
# Fail To Load Key: ['classifier.header.pointwise_conv.conv.weight', 'classifier.header.pointwise_conv.conv.bias'] ……
# Fail To Load Key num: 2
#
# 温馨提示，head部分没有载入是正常现象，Backbone部分没有载入是错误的。
# ...

# %%
# %cd /content/efficientdet-pytorch/
# !python get_map.py
# Out:
# /content/efficientdet-pytorch
# Load model.
# logs/best_epoch_weights.pth model, anchors, and classes loaded.
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ----------------------------------------------------------------------
# |               model_path |              logs/best_epoch_weights.pth|
# |             classes_path |               model_data/cls_classes.txt|
# |                      phi |                                        0|
# |               confidence |                                     0.02|
# |                  nms_iou |                                      0.5|
# |          letterbox_image |                                    False|
# |                     cuda |                                     True|
# ----------------------------------------------------------------------
# Load model done.
# Get predict result.
# ...

# %%
# %cd /content/efficientdet-pytorch/
# !python get_map.py
# Out:
# /content/efficientdet-pytorch
# Load model.
# logs/best_epoch_weights.pth model, anchors, and classes loaded.
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ----------------------------------------------------------------------
# |               model_path |              logs/best_epoch_weights.pth|
# |             classes_path |               model_data/cls_classes.txt|
# |                      phi |                                        0|
# |               confidence |                                     0.02|
# |                  nms_iou |                                      0.5|
# |          letterbox_image |                                    False|
# |                     cuda |                                     True|
# ----------------------------------------------------------------------
# Load model done.
# Get predict result.
# ...

# %%
# %cd /content/efficientdet-pytorch/
# !python get_map.py
# Out:
# /content/efficientdet-pytorch
# Load model.
# logs/best_epoch_weights.pth model, anchors, and classes loaded.
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ----------------------------------------------------------------------
# |               model_path |              logs/best_epoch_weights.pth|
# |             classes_path |               model_data/cls_classes.txt|
# |                      phi |                                        0|
# |               confidence |                                     0.02|
# |                  nms_iou |                                      0.5|
# |          letterbox_image |                                    False|
# |                     cuda |                                     True|
# ----------------------------------------------------------------------
# Load model done.
# Get predict result.
# ...

# %%
# %cp -rv "/content/EfficientDet" "/content/drive/MyDrive/Final Submission/EfficientDet_512x512"
# Out:
# '/content/EfficientDet' -> '/content/drive/MyDrive/Final Submission/EfficientDet_512x512/EfficientDet'
# '/content/EfficientDet/VOCdevkit.zip' -> '/content/drive/MyDrive/Final Submission/EfficientDet_512x512/EfficientDet/VOCdevkit.zip'
# '/content/EfficientDet/efficientdet-pytorch' -> '/content/drive/MyDrive/Final Submission/EfficientDet_512x512/EfficientDet/efficientdet-pytorch'
# '/content/EfficientDet/efficientdet-pytorch/.git' -> '/content/drive/MyDrive/Final Submission/EfficientDet_512x512/EfficientDet/efficientdet-pytorch/.git'
# '/content/EfficientDet/efficientdet-pytorch/.git/branches' -> '/content/drive/MyDrive/Final Submission/EfficientDet_512x512/EfficientDet/efficientdet-pytorch/.git/branches'
# '/content/EfficientDet/efficientdet-pytorch/.git/description' -> '/content/drive/MyDrive/Final Submission/EfficientDet_512x512/EfficientDet/efficientdet-pytorch/.git/description'
# ...
